# %% [markdown]
# # Esse é um notebook
#
# ## Trecho com texto
#
# O notebooks reconhecem o estilo de marcação de texto conhecido como `markdown`.

# %%
## Trecho de código

# Essa parte será interpretada como código python e o resultado será apresentado abaixo da célula:
print(1 + 1)
print('Hello from a notebook')
# Out:
# 2
# Hello from a notebook

# %%
# plotting graphs
import pylab
import numpy as np

# %matplotlib inline

x = np.linspace(0, 20, 1000)  # 100 evenly-spaced values from 0 to 50
y = np.sin(x)

pylab.plot(x, y)
